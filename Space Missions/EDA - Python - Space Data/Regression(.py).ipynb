# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/shrey/Downloads/IBM/Year Count.csv")
data
# Out:
#     Years  Missions  Cost  Success
# 0    1957         3     3        2
# 1    1958        28    28        6
# 2    1959        20    20        8
# 3    1960        39    39       19
# 4    1961        52    52       32
# ..    ...       ...   ...      ...
# 59   2016        90  2116       86
# 60   2017        92  2469       84
# 61   2018       117  3327      113
# 62   2019       109  2883      100
# 63   2020        63  1839       57
#
# [64 rows x 4 columns]

# %%
sns.lmplot(x="Years", y="Missions", data=data);

# %%
sns.lmplot(x="Years", y="Cost", data=data);

# %%
sns.lmplot(x="Years", y="Success", data=data);

# %%
sns.lmplot(x="Missions", y="Cost", data=data);

# %%
sns.lmplot(x="Missions", y="Success", data=data);

# %%
sns.lmplot(x="Cost", y="Success", data=data);
